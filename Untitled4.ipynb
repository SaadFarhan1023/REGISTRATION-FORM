# %%
import tkinter as tk
from tkinter import ttk
from tkinter import*

registrationform=Tk()
registrationform.title("Registration Form")
registrationform.geometry("2000x1000")

data=registrationform
data.geometry("500x150")
a=Label(data,text=("REGISTRATION FORM"),font=("arial",20,"bold"),fg="black")
a.grid(row=0,column=0)

name=registrationform
name.geometry('400x250')
a=tk.Label(name,text='full name').place(x = 30,y=50)
b=tk.Label(name,text='email').place(x=30,y=90)
entry1=tk.Entry(name).place(x=85,y=50)
entry2=tk.Entry(name).place(x=85,y=90)
 
root=registrationform
tk.Label(root,text='gender',justify=tk.LEFT,padx=20).grid(row=8,column=1)
v=IntVar()
tk.Radiobutton(root,text='male',padx=20,variable=v,value=1).grid(row=8,column=2)
tk.Radiobutton(root,text='female',padx=20,variable=v,value=2).grid(row=8,column=3)

window=registrationform
window.title('Combobox')
window.geometry('500x250')

ttk.Label(window,text='Country:',
          font = ('Times New Roman',10)).grid(row=9,column=3,padx = 10,pady = 25)
n =StringVar()
monthchoosen = ttk.Combobox(window,width=27,textvariable=n)
 
monthchoosen['values']=('select your country','Pakistan','Australia', 'New Zealand')

monthchoosen.grid(row=9,column=4)
monthchoosen.current(0)

master=registrationform
master.geometry("300x120")
a=Label(master,text="PROGRAMMING",justify=tk.LEFT,padx=20).grid(row=10,column=5)

var1=IntVar()
check1=Checkbutton(master,text="JAVA",variable=var1)
check1.deselect()
check1.grid(row=10,column=6)

var2=IntVar()
check2=Checkbutton(master,text="PYTHON",variable=var2)
check2.select()
check2.grid(row=10,column=7)
def info():
    print('Submit')
    
lose=registrationform
a=Button(lose,text='Submit',bg='red',fg='black',command=info)
a.grid(row=11,column=0)
registrationform.mainloop()
# Out:
# Submit
# Submit

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import*

registrationform=Tk()
registrationform.title("Registration Form")
registrationform.geometry("2000x1000")

data=registrationform
data.geometry("500x150")
a=Label(data,text=("REGISTRATION FORM"),font=("arial",20,"bold"),fg="black")
a.pack(fill=X,side=LEFT)

name=registrationform
name.geometry('400x250')
a=tk.Label(name,text='full name').place(x = 30,y=50)
b=tk.Label(name,text='email').place(x=30,y=90)
entry1=tk.Entry(name).place(x=85,y=50)
entry2=tk.Entry(name).place(x=85,y=90)
 
root=registrationform
tk.Label(root,text='gender',justify=tk.LEFT,padx=20).pack()
v=IntVar()
tk.Radiobutton(root,text='male',padx=20,variable=v,value=1).pack(anchor=tk.W)
tk.Radiobutton(root,text='female',padx=20,variable=v,value=2).pack(anchor=tk.W)

window=registrationform
window.title('Combobox')
window.geometry('500x250')

ttk.Label(window,text='Country:',
          font = ('Times New Roman',10)).pack(fill=X,side=LEFT,padx = 10,pady = 25)
n =StringVar()
monthchoosen = ttk.Combobox(window,width=27,textvariable=n)
 
monthchoosen['values']=('select your country',
                       'Pakistan',
                       'Australia',
                       'New Zealand')

monthchoosen.pack(fill=X,side=LEFT)
monthchoosen.current(0)
master=registrationform
master.geometry("300x120")
a=Label(master,text="PROGRAMMING",justify=tk.LEFT,padx=20).pack(fill=X,side=LEFT)

var1=IntVar()
check1=Checkbutton(master,text="JAVA",variable=var1)
check1.deselect()
check1.pack(fill=X,side=LEFT)

var2=IntVar()
check2=Checkbutton(master,text="PYTHON",variable=var2)
check2.select()
check2.pack(fill=X,side=LEFT)

def info():
    print('Submit')
    
lose=registrationform
a=Button(lose,text='Submit',bg='red',fg='black',command=info)
a.pack(fill=X,side=LEFT)

registrationform.mainloop()
